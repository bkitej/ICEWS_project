# %% [markdown]
# ### R experiments with Dataverse client API
#
# Ben Johnson
#
# 3/23/2019
#
# start time: 7:00pm
#
# break start: 8:40pm
#
# break end: 9:40pm
#
# end time: 11:40pm

# %% [markdown]
# The purpose of this script is to access the ICEWS dataverse API through the R client. Would prefer to use Python but having trouble with "authorization," even though it's an open dataset. Let's see if using R instead gets us the results we want.

# %% [markdown]
# Tasks:
#
# 1. **✔** access ICEWS files through [Dataverse API client for R](https://github.com/IQSS/dataverse-client-r)

# %% [markdown]
# Results:
# 1. Partial success, but promising. I followed the examples [here](https://github.com/IQSS/dataverse-client-r) and [here](https://www.rdocumentation.org/packages/dataverse/versions/0.2.0/topics/get_file), and skimmed the docs in relevant places. The pipeline should follow something like this:
#     - access ICEWS *dataverse* class
#     - access most recent ICEWS datase from the *dataverse_dataset* list within
#     - get *dataFile.id* attribute, which returns a numerical handle for each unique dataset
#     - make get_file() calls on handles
#     - unzip the results to .tab files
# I can pretty much finish this up with built-in utilities at any time, but I spent a lot of time trying to use API functions directly. Giving up on that for now.

# %%
# set system environment variables
# not sure if this is strictly needed for an open dataset? We're not posting anything.

# Sys.setenv('DATAVERSE_KEY' = key...)
Sys.setenv('DATAVERSE_SERVER' = 'dataverse.harvard.edu')

# %%
# example download from https://www.rdocumentation.org/packages/dataverse/versions/0.2.0/topics/get_file
monogan <- get_dataverse("monogan")
monogan_data <- dataverse_contents(monogan)
d1 <- get_dataset("doi:10.7910/DVN/ARKOTI")

# breaks every time. Again, copy pasted from example. 
f <- get_file(d1$files$datafile$id[3], "doi:10.7910/DVN/ARKOTI")
# Out:
# Error in get_fileid.character(dataset, file, key = key, server = server, : File not found
# Traceback:
#
# 1. get_file(d1$files$datafile$id[3], "doi:10.7910/DVN/ARKOTI")
# 2. get_fileid(dataset, file, key = key, server = server, ...)
# 3. get_fileid.character(dataset, file, key = key, server = server,
#  .     ...)
# 4. stop("File not found")

# %%
# here's the problem... attributes aren't easy to get?
d1$files
# Out:
# ERROR while rich displaying an object: Error in vapply(part, format, character(nrow(part))): values must be length 32,
#  but FUN(X[[10]]) result is length 2
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     rpr <- mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. mime2repr[[mime]](obj)
# 8. repr_text.data.frame(obj)
# 9. ellip_limit_arr(obj, ...)
# 10. arr_parts_format(parts)
# 11. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 12. lapply(parts, arr_part_format)
# 13. FUN(X[[i]], ...)
# 14. vapply(part, format, character(nrow(part)))

# %%
# another example. Once we've gotten the file name/numerical id, everything's pretty smooth from there.
get_dataset("doi:10.7910/DVN/ARKOTI")

f <- get_file("constructionData.tab", "doi:10.7910/DVN/ARKOTI")

# load into memory. These are stata files, I believe; not sure how to adapt this to ICEWS .zip files, or if I should even worry about that this early.
tmp <- tempfile(fileext = ".dta")
writeBin(as.vector(f), tmp)
dat <- foreign::read.dta(tmp)
# Out:
# Dataset (75170):
# Version: 1.0, RELEASED
# Release Date: 2015-07-07T02:57:02Z
# License: CC0
# 21 Files:
#                           label version      id                  contentType
# 1                  alpl2013.tab       2 2692294    text/tab-separated-values
# 2                   BPchap7.tab       2 2692295    text/tab-separated-values
# 3                   chapter01.R       2 2692202 text/plain; charset=US-ASCII
# 4                   chapter02.R       2 2692206 text/plain; charset=US-ASCII
# 5                   chapter03.R       2 2692210 text/plain; charset=US-ASCII
# 6                   chapter04.R       2 2692204 text/plain; charset=US-ASCII
# 7                   chapter05.R       2 2692205 text/plain; charset=US-ASCII
# 8                   chapter06.R       2 2692212 text/plain; charset=US-ASCII
# 9                   chapter07.R       2 2692209 text/plain; charset=US-ASCII
# 10                  chapter08.R       2 2692208 text/plain; charset=US-ASCII
# 11                  chapter09.R       2 2692211 text/plain; charset=US-ASCII
# 12                  chapter10.R       1 2692203 text/plain; charset=US-ASCII
# 13                  chapter11.R       1 2692207 text/plain; charset=US-ASCII
# 14 comprehensiveJapanEnergy.tab       2 2692296    text/tab-separated-values
# 15         constructionData.tab       2 2692293    text/tab-separated-values
# 16             drugCoverage.csv       1 2692233 text/plain; charset=US-ASCII
# 17         hanmerKalkanANES.tab       2 2692290    text/tab-separated-values
# 18                 hmnrghts.tab       2 2692298    text/tab-separated-values
# 19                 hmnrghts.txt       1 2692238                   text/plain
# 20                   levant.tab       2 2692289    text/tab-separated-values
# 21                       LL.csv       1 2692228 text/plain; charset=US-ASCII
# 22                 moneyDem.tab       2 2692292    text/tab-separated-values
# 23            owsiakJOP2013.tab       2 2692297    text/tab-separated-values
# 24                PESenergy.csv       1 2692230 text/plain; charset=US-ASCII
# 25                  pts1994.csv       1 2692229 text/plain; charset=US-ASCII
# 26                  pts1995.csv       1 2692231 text/plain; charset=US-ASCII
# 27                 sen113kh.ord       1 2692239 text/plain; charset=US-ASCII
# 28                SinghEJPR.tab       2 2692299    text/tab-separated-values
# 29                 SinghJTP.tab       2 2692288    text/tab-separated-values
# 30                 stdSingh.tab       2 2692291    text/tab-separated-values
# 31                       UN.csv       1 2692232 text/plain; charset=US-ASCII
# 32                  war1800.tab       2 2692300    text/tab-separated-values

# %%
# ICEWS dataverse main handle
icews_doi = 'doi:10.7910/DVN/QI2T9A'

# %%
# this is pretty much exactly what we want, but I can't find out how to access it.
(icews_dataset = get_dataset(icews_doi))
# Out:
# Dataset (151508):
# Version: 151.0, RELEASED
# Release Date: 2019-03-24T04:50:57Z
# License: CC0
# 16 Files:
#                         label version      id     contentType
# 1   20181004-icews-events.zip       1 3234868 application/zip
# 2   20181005-icews-events.zip       1 3235021 application/zip
# 3   20181006-icews-events.zip       1 3238491 application/zip
# 4   20181007-icews-events.zip       1 3238493 application/zip
# 5   20181008-icews-events.zip       1 3238584 application/zip
# 6   20181009-icews-events.zip       1 3238918 application/zip
# 7   20181010-icews-events.zip       1 3239379 application/zip
# 8   20181011-icews-events.zip       1 3239478 application/zip
# 9   20181012-icews-events.zip       1 3239713 application/zip
# 10  20181013-icews-events.zip       1 3239773 application/zip
# 11  20181014-icews-events.zip       1 3240169 application/zip
# 12  20181015-icews-events.zip       1 3241107 application/zip
# 13  20181016-icews-events.zip       1 3241682 application/zip
# 14  20181017-icews-events.zip       1 3241758 application/zip
# 15  20181018-icews-events.zip       1 3241924 application/zip
# 16  20181019-icews-events.zip       1 3242281 application/zip
# 17  20181020-icews-events.zip       1 3242317 application/zip
# 18  20181021-icews-events.zip       1 3242403 application/zip
# 19  20181022-icews-events.zip       1 3242604 application/zip
# 20  20181023-icews-events.zip       1 3243675 application/zip
# 21  20181024-icews-events.zip       1 3246558 application/zip
# 22  20181025-icews-events.zip       1 3246896 application/zip
# 23  20181026-icews-events.zip       1 3249493 application/zip
# 24  20181027-icews-events.zip       1 3249534 application/zip
# 25  20181028-icews-events.zip       1 3298475 application/zip
# 26  20181029-icews-events.zip       1 3298694 application/zip
# 27  20181030-icews-events.zip       1 3298971 application/zip
# 28  20181031-icews-events.zip       1 3300260 application/zip
# 29  20181101-icews-events.zip       1 3300871 application/zip
# 30  20181102-icews-events.zip       1 3301928 application/zip
# 31  20181103-icews-events.zip       1 3302008 application/zip
# 32  20181104-icews-events.zip       1 3308419 application/zip
# 33  20181105-icews-events.zip       1 3308646 application/zip
# 34  20181106-icews-events.zip       1 3309847 application/zip
# 35  20181107-icews-events.zip       1 3312181 application/zip
# 36  20181108-icews-events.zip       1 3312378 application/zip
# 37  20181109-icews-events.zip       1 3312606 application/zip
# 38  20181110-icews-events.zip       1 3314148 application/zip
# 39  20181111-icews-events.zip       1 3314716 application/zip
# 40  20181112-icews-events.zip       1 3314833 application/zip
# 41  20181113-icews-events.zip       1 3314937 application/zip
# 42  20181114-icews-events.zip       1 3316995 application/zip
# 43  20181115-icews-events.zip       1 3316997 application/zip
# 44  20181116-icews-events.zip       1 3316998 application/zip
# 45  20181117-icews-events.zip       1 3316999 application/zip
# 46  20181118-icews-events.zip       1 3317000 application/zip
# 47  20181119-icews-events.zip       1 3317105 application/zip
# 48  20181120-icews-events.zip       1 3317244 application/zip
# 49  20181121-icews-events.zip       1 3317421 application/zip
# 50  20181122-icews-events.zip       1 3317708 application/zip
# 51  20181123-icews-events.zip       1 3317787 application/zip
# 52  20181124-icews-events.zip       1 3318031 application/zip
# 53  20181125-icews-events.zip       1 3318842 application/zip
# 54  20181126-icews-events.zip       1 3319710 application/zip
# 55  20181127-icews-events.zip       1 3319853 application/zip
# 56  20181128-icews-events.zip       1 3320141 application/zip
# 57  20181129-icews-events.zip       1 3320359 application/zip
# 58  20181130-icews-events.zip       1 3320542 application/zip
# 59  20181203-icews-events.zip       1 3323316 application/zip
# 60  20181204-icews-events.zip       1 3323614 application/zip
# 61  20181205-icews-events.zip       1 3324241 application/zip
# 62  20181206-icews-events.zip       1 3324451 application/zip
# 63  20181207-icews-events.zip       1 3324614 application/zip
# 64  20181208-icews-events.zip       1 3324660 application/zip
# 65  20181209-icews-events.zip       1 3326255 application/zip
# 66  20181210-icews-events.zip       1 3326558 application/zip
# 67  20181211-icews-events.zip       1 3329755 application/zip
# 68  20181212-icews-events.zip       1 3329936 application/zip
# 69  20181213-icews-events.zip       1 3330645 application/zip
# 70  20181214-icews-events.zip       1 3330911 application/zip
# 71  20181215-icews-events.zip       1 3332392 application/zip
# 72  20181216-icews-events.zip       1 3332510 application/zip
# 73  20181217-icews-events.zip       1 3332904 application/zip
# 74  20181218-icews-events.zip       1 3333301 application/zip
# 75  20181219-icews-events.zip       1 3333628 application/zip
# 76  20181220-icews-events.zip       1 3333772 application/zip
# 77  20181221-icews-events.zip       1 3333975 application/zip
# 78  20181222-icews-events.zip       1 3337596 application/zip
# 79  20181223-icews-events.zip       1 3337597 application/zip
# 80  20181224-icews-events.zip       1 3337598 application/zip
# 81  20181225-icews-events.zip       1 3337599 application/zip
# 82  20181226-icews-events.zip       1 3337600 application/zip
# 83  20181227-icews-events.zip       1 3337601 application/zip
# 84  20181228-icews-events.zip       1 3337602 application/zip
# 85  20181229-icews-events.zip       1 3337603 application/zip
# 86  20181230-icews-events.zip       1 3337604 application/zip
# 87  20181231-icews-events.zip       1 3337605 application/zip
# 88  20190101-icews-events.zip       1 3337606 application/zip
# 89  20190102-icews-events.zip       1 3337607 application/zip
# 90  20190103-icews-events.zip       1 3337608 application/zip
# 91  20190104-icews-events.zip       1 3337630 application/zip
# 92  20190105-icews-events.zip       1 3337648 application/zip
# 93  20190106-icews-events.zip       1 3337686 application/zip
# 94  20190107-icews-events.zip       1 3338310 application/zip
# 95  20190108-icews-events.zip       1 3339220 application/zip
# 96  20190109-icews-events.zip       1 3340522 application/zip
# 97  20190110-icews-events.zip       1 3344121 application/zip
# 98  20190111-icews-events.zip       1 3344489 application/zip
# 99  20190112-icews-events.zip       1 3344662 application/zip
# 100 20190113-icews-events.zip       1 3344730 application/zip
# 101 20190114-icews-events.zip       1 3344814 application/zip
# 102 20190115-icews-events.zip       1 3344929 application/zip
# 103 20190116-icews-events.zip       1 3345449 application/zip
# 104 20190117-icews-events.zip       1 3345450 application/zip
# 105 20190118-icews-events.zip       1 3346475 application/zip
# 106 20190119-icews-events.zip       1 3346476 application/zip
# 107 20190120-icews-events.zip       1 3346477 application/zip
# 108 20190121-icews-events.zip       1 3346663 application/zip
# 109 20190122-icews-events.zip       1 3346873 application/zip
# 110 20190123-icews-events.zip       1 3346971 application/zip
# 111 20190124-icews-events.zip       1 3347274 application/zip
# 112 20190125-icews-events.zip       1 3347585 application/zip
# 113 20190126-icews-events.zip       1 3347811 application/zip
# 114 20190127-icews-events.zip       1 3348320 application/zip
# 115 20190128-icews-events.zip       1 3348680 application/zip
# 116 20190129-icews-events.zip       1 3349094 application/zip
# 117 20190130-icews-events.zip       1 3349359 application/zip
# 118 20190131-icews-events.zip       1 3349524 application/zip
# 119 20190201-icews-events.zip       1 3350396 application/zip
# 120 20190202-icews-events.zip       1 3350722 application/zip
# 121 20190203-icews-events.zip       1 3350747 application/zip
# 122 20190204-icews-events.zip       1 3350994 application/zip
# 123 20190205-icews-events.zip       1 3354195 application/zip
# 124 20190206-icews-events.zip       1 3354514 application/zip
# 125 20190207-icews-events.zip       1 3354892 application/zip
# 126 20190208-icews-events.zip       1 3355363 application/zip
# 127 20190211-icews-events.zip       1 3357452 application/zip
# 128 20190212-icews-events.zip       1 3357554 application/zip
# 129 20190213-icews-events.zip       1 3357699 application/zip
# 130 20190214-icews-events.zip       1 3360844 application/zip
# 131 20190215-icews-events.zip       1 3362203 application/zip
# 132 20190216-icews-events.zip       1 3362266 application/zip
# 133 20190217-icews-events.zip       1 3362273 application/zip
# 134 20190218-icews-events.zip       1 3364293 application/zip
# 135 20190219-icews-events.zip       1 3365277 application/zip
# 136 20190220-icews-events.zip       1 3370401 application/zip
# 137 20190221-icews-events.zip       1 3370578 application/zip
# 138 20190222-icews-events.zip       1 3371154 application/zip
# 139 20190223-icews-events.zip       1 3371183 application/zip
# 140 20190224-icews-events.zip       1 3371223 application/zip
# 141 20190225-icews-events.zip       1 3371553 application/zip
# 142 20190226-icews-events.zip       1 3372147 application/zip
# 143 20190227-icews-events.zip       1 3373117 application/zip
# 144 20190228-icews-events.zip       1 3373626 application/zip
# 145 20190301-icews-events.zip       1 3373922 application/zip
# 146 20190302-icews-events.zip       1 3374037 application/zip
# 147 20190303-icews-events.zip       1 3376340 application/zip
# 148 20190304-icews-events.zip       1 3376530 application/zip
# 149 20190305-icews-events.zip       1 3376746 application/zip
# 150 20190306-icews-events.zip       1 3376828 application/zip
# 151 20190307-icews-events.zip       1 3377068 application/zip
# 152 20190308-icews-events.zip       1 3377299 application/zip
# 153 20190309-icews-events.zip       1 3377732 application/zip
# 154 20190309-icews-events.zip       1 3377320 application/zip
# 155 20190311-icews-events.zip       1 3377961 application/zip
# 156 20190312-icews-events.zip       1 3378405 application/zip
# 157 20190313-icews-events.zip       1 3378464 application/zip
# 158 20190314-icews-events.zip       1 3379013 application/zip
# 159 20190315-icews-events.zip       1 3379435 application/zip
# 160 20190316-icews-events.zip       1 3379648 application/zip
# 161 20190317-icews-events.zip       1 3379725 application/zip
# 162 20190318-icews-events.zip       1 3380832 application/zip
# 163 20190319-icews-events.zip       1 3381850 application/zip
# 164 20190320-icews-events.zip       1 3382048 application/zip
# 165 20190321-icews-events.zip       1 3382524 application/zip
# 166 20190322-icews-events.zip       1 3382662 application/zip
# 167 20190323-icews-events.zip       1 3382959 application/zip

# %%
# 'files' attribute clearly visible...
attributes(icews_dataset)
# Out:
# $names
#  [1] "id"                 "storageIdentifier"  "versionNumber"
#  [4] "versionMinorNumber" "versionState"       "productionDate"
#  [7] "lastUpdateTime"     "releaseTime"        "createTime"
# [10] "license"            "termsOfUse"         "metadataBlocks"
# [13] "files"
#
# $class
# [1] "dataverse_dataset"

# %%
# top-level look at the ICEWS dataset

# object containing all data about the ICEWS dataverse account
(icews = get_dataverse('icews'))
# Out:
# Dataverse (2900): icews
# Name:        Integrated Crisis Early Warning System (ICEWS) Dataverse
# Description: Data produced for the Integrated Crisis Early Warning System (ICEWS) for the Defense Advanced Research Projects Agency (DARPA) and Office of Naval Research (ONR). Follow our Twitter handle for data updates and other news: @icews
# Created:     2014-12-08T16:01:26Z
# Creator:     @jlautens

# %%
# list of all ICEWS dataSETS, not FILES of the dataset that concerns us
(icews_data = dataverse_contents(icews))
# Out:
# [[1]]
# Dataset (3234391): https://doi.org/10.7910/DVN/QI2T9A
# Publisher: Harvard Dataverse
# publicationDate: 2018-10-04
#
#
# [[2]]
# Dataset (65871): https://doi.org/10.7910/DVN/28118
# Publisher: Harvard Dataverse
# publicationDate: 2015-03-27
#
#
# [[3]]
# Dataset (65872): https://doi.org/10.7910/DVN/28119
# Publisher: Harvard Dataverse
# publicationDate: 2015-03-27
#
#
# [[4]]
# Dataset (65873): https://doi.org/10.7910/DVN/28117
# Publisher: Harvard Dataverse
# publicationDate: 2015-03-27
#
#
# [[5]]
# Dataset (65874): https://doi.org/10.7910/DVN/28075
# Publisher: Harvard Dataverse
# publicationDate: 2015-03-27

# %%
# all .zips
(data_list = dataset_files(icews_doi))
# Out:
# [[1]]
# File (3234868): 20181004-icews-events.zip
# Dataset version: 151508
# MD5: 9a9a3bcca7df7c6eef0f161fd3cdcd7a
# Description:
#
# [[2]]
# File (3235021): 20181005-icews-events.zip
# Dataset version: 151508
# MD5: 8123db0735e7b9bb85b24e36b19103b9
# Description:
#
# [[3]]
# File (3238491): 20181006-icews-events.zip
# Dataset version: 151508
# MD5: 97fa48cf7c903273a5cc22220b288571
# Description:
#
# [[4]]
# File (3238493): 20181007-icews-events.zip
# Dataset version: 151508
# MD5: b7e3e1725a2c43a0a2f079ff02fe5af2
# Description:
#
# [[5]]
# File (3238584): 20181008-icews-events.zip
# Dataset version: 151508
# MD5: ae100a6f60570c10a6773870340006fc
# Description:
#
# [[6]]
# File (3238918): 20181009-icews-events.zip
# Dataset version: 151508
# MD5: 0c1d3761f0942510b0c79aa485c4bbb2
# Description:
#
# [[7]]
# File (3239379): 20181010-icews-events.zip
# Dataset version: 151508
# MD5: 9167c7f3752432db37998c19fdb7d7cf
# Description:
#
# [[8]]
# File (3239478): 20181011-icews-events.zip
# Dataset version: 151508
# MD5: eba7ab008b520200043b2c373f440031
# Description:
#
# [[9]]
# File (3239713): 20181012-icews-events.zip
# Dataset version: 151508
# MD5: ca5413473003df9d1e8a7298392cd6da
# Description:
#
# [[10]]
# File (3239773): 20181013-icews-events.zip
# Dataset version: 151508
# MD5: 4910cb00a3bde85df9abd36516808952
# Description:
#
# [[11]]
# File (3240169): 20181014-icews-events.zip
# Dataset version: 151508
# MD5: d128e1b17a8e33bfc3e027b44d626327
# Description:
#
# [[12]]
# File (3241107): 20181015-icews-events.zip
# Dataset version: 151508
# MD5: 4fe0fbedd6e729c74a37fcaaaffb7c79
# Description:
#
# [[13]]
# File (3241682): 20181016-icews-events.zip
# Dataset version: 151508
# MD5: 5b7f879cfa5a86851da3ec843d8e9e15
# Description:
#
# [[14]]
# File (3241758): 20181017-icews-events.zip
# Dataset version: 151508
# MD5: 8e11d578e810dd29f1ac04d2b21b73e4
# Description:
#
# [[15]]
# File (3241924): 20181018-icews-events.zip
# Dataset version: 151508
# MD5: a9a12f52a42861c6c3b866fa924b658b
# Description:
#
# [[16]]
# File (3242281): 20181019-icews-events.zip
# Dataset version: 151508
# MD5: 2f44e5fa73c82df2dd0a8eb26c0e730b
# Description:
#
# [[17]]
# File (3242317): 20181020-icews-events.zip
# Dataset version: 151508
# MD5: 2259d13edec4eed9c3cc1cec48d58d84
# Description:
#
# [[18]]
# File (3242403): 20181021-icews-events.zip
# Dataset version: 151508
# MD5: a40186fb83f41069282b6bdd112a7331
# Description:
#
# [[19]]
# File (3242604): 20181022-icews-events.zip
# Dataset version: 151508
# MD5: 5cac5d4e4e27e5f4295222f702360849
# Description:
#
# [[20]]
# File (3243675): 20181023-icews-events.zip
# Dataset version: 151508
# MD5: b3309f4266b59782d7a8030d11215b23
# Description:
#
# [[21]]
# File (3246558): 20181024-icews-events.zip
# Dataset version: 151508
# MD5: 6f8fdd9ce659083347ceb99a17647c51
# Description:
#
# [[22]]
# File (3246896): 20181025-icews-events.zip
# Dataset version: 151508
# MD5: eab698663e16e849358d89e2f5d3ac2b
# Description:
#
# [[23]]
# File (3249493): 20181026-icews-events.zip
# Dataset version: 151508
# MD5: ed3228024d30b684082a27ecf814a298
# Description:
#
# [[24]]
# File (3249534): 20181027-icews-events.zip
# Dataset version: 151508
# MD5: 17e2f1439ebbf6ffaedaeff579c7c194
# Description:
#
# [[25]]
# File (3298475): 20181028-icews-events.zip
# Dataset version: 151508
# MD5: 4bc016682813c231b941254d5e3ad604
# Description:
#
# [[26]]
# File (3298694): 20181029-icews-events.zip
# Dataset version: 151508
# MD5: a77e08e6c47967f4889f2c7774653f8a
# Description:
#
# [[27]]
# File (3298971): 20181030-icews-events.zip
# Dataset version: 151508
# MD5: d6823ed9fb4a41b4db68cf689e787681
# Description:
#
# [[28]]
# File (3300260): 20181031-icews-events.zip
# Dataset version: 151508
# MD5: 1ab03fb5954726953a351488dc30932c
# Description:
#
# [[29]]
# File (3300871): 20181101-icews-events.zip
# Dataset version: 151508
# MD5: d4a1a18b8cd172cdd36e53789c2269dc
# Description:
#
# [[30]]
# File (3301928): 20181102-icews-events.zip
# Dataset version: 151508
# MD5: f1927b675cb436737333feb1cebd4b38
# Description:
#
# [[31]]
# File (3302008): 20181103-icews-events.zip
# Dataset version: 151508
# MD5: 5c0bfbe13863a458df36c1f2c699f493
# Description:
#
# [[32]]
# File (3308419): 20181104-icews-events.zip
# Dataset version: 151508
# MD5: 173959d907c7b1ade49cceeed1b5dfc8
# Description:
#
# [[33]]
# File (3308646): 20181105-icews-events.zip
# Dataset version: 151508
# MD5: 14f1baba01113d01c42c7ae35aea4542
# Description:
#
# [[34]]
# File (3309847): 20181106-icews-events.zip
# Dataset version: 151508
# MD5: 48cffc908a81043fcc67e0c5e8e6294f
# Description:
#
# [[35]]
# File (3312181): 20181107-icews-events.zip
# Dataset version: 151508
# MD5: 16be09e84f7e1d8985b4426e825beca2
# Description:
#
# [[36]]
# File (3312378): 20181108-icews-events.zip
# Dataset version: 151508
# MD5: 961dbc75b103a8fed5c8ebd664fa137d
# Description:
#
# [[37]]
# File (3312606): 20181109-icews-events.zip
# Dataset version: 151508
# MD5: 9ca2d3c91229783fe2923f8e8bbbd3dd
# Description:
#
# [[38]]
# File (3314148): 20181110-icews-events.zip
# Dataset version: 151508
# MD5: eb4e227d66463bf3e07c8e120e1ecdad
# Description:
#
# [[39]]
# File (3314716): 20181111-icews-events.zip
# Dataset version: 151508
# MD5: 3d7dde7dadd1cae8157fe0647263d5cc
# Description:
#
# [[40]]
# File (3314833): 20181112-icews-events.zip
# Dataset version: 151508
# MD5: ad779f3c02409a2c58c3b120af688158
# Description:
#
# [[41]]
# File (3314937): 20181113-icews-events.zip
# Dataset version: 151508
# MD5: 58c425bca5778775b1f7eb3455595526
# Description:
#
# [[42]]
# File (3316995): 20181114-icews-events.zip
# Dataset version: 151508
# MD5: 4cb81e520540c42e7feadcef9e2e62a9
# Description:
#
# [[43]]
# File (3316997): 20181115-icews-events.zip
# Dataset version: 151508
# MD5: 4bc1099aa8d4d43cd84c3a8120cafc86
# Description:
#
# [[44]]
# File (3316998): 20181116-icews-events.zip
# Dataset version: 151508
# MD5: 0a870e82a13accf1af9a94a77bd4d9bc
# Description:
#
# [[45]]
# File (3316999): 20181117-icews-events.zip
# Dataset version: 151508
# MD5: 6c4ec34c39dd15f4cf1dc0fc4a5f0558
# Description:
#
# [[46]]
# File (3317000): 20181118-icews-events.zip
# Dataset version: 151508
# MD5: 1942f6e3ef843f28be336cf65b2c1ff4
# Description:
#
# [[47]]
# File (3317105): 20181119-icews-events.zip
# Dataset version: 151508
# MD5: c40cd69798a6d7744e8a822ed6188b63
# Description:
#
# [[48]]
# File (3317244): 20181120-icews-events.zip
# Dataset version: 151508
# MD5: 9e3bd284e10ad68b31106855f034c0b9
# Description:
#
# [[49]]
# File (3317421): 20181121-icews-events.zip
# Dataset version: 151508
# MD5: 4204e4e15f50cceebfdbe68184b8fd07
# Description:
#
# [[50]]
# File (3317708): 20181122-icews-events.zip
# Dataset version: 151508
# MD5: c6109d7b9c8f9790385f56fed26f209a
# Description:
#
# [[51]]
# File (3317787): 20181123-icews-events.zip
# Dataset version: 151508
# MD5: d1a663dc6ab6f08d6e20473101b32934
# Description:
#
# [[52]]
# File (3318031): 20181124-icews-events.zip
# Dataset version: 151508
# MD5: a41f186d71459603e933bfde58742162
# Description:
#
# [[53]]
# File (3318842): 20181125-icews-events.zip
# Dataset version: 151508
# MD5: c687bf4830300fa18e52e9c9fbf4fb07
# Description:
#
# [[54]]
# File (3319710): 20181126-icews-events.zip
# Dataset version: 151508
# MD5: d109618e9a532e034dd0292829deba50
# Description:
#
# [[55]]
# File (3319853): 20181127-icews-events.zip
# Dataset version: 151508
# MD5: de51d93fc4e4f0fe182500d9dbb1f330
# Description:
#
# [[56]]
# File (3320141): 20181128-icews-events.zip
# Dataset version: 151508
# MD5: eaba4ffdb5734b14324188e1fb8fb69e
# Description:
#
# [[57]]
# File (3320359): 20181129-icews-events.zip
# Dataset version: 151508
# MD5: fedb27da712b3d93e736221740460013
# Description:
#
# [[58]]
# File (3320542): 20181130-icews-events.zip
# Dataset version: 151508
# MD5: 285ff54c897445ab8d022f0ef3d58492
# Description:
#
# [[59]]
# File (3323316): 20181203-icews-events.zip
# Dataset version: 151508
# MD5: 28a6b1437327308c0b3b528907db5353
# Description:
#
# [[60]]
# File (3323614): 20181204-icews-events.zip
# Dataset version: 151508
# MD5: 931a5f0e620cd3546a07833e330ad28e
# Description:
#
# [[61]]
# File (3324241): 20181205-icews-events.zip
# Dataset version: 151508
# MD5: a1fbfe98ab2b98a3607d23b6c86651b0
# Description:
#
# [[62]]
# File (3324451): 20181206-icews-events.zip
# Dataset version: 151508
# MD5: 56dca042f810833e4fb01b51e60d32f4
# Description:
#
# [[63]]
# File (3324614): 20181207-icews-events.zip
# Dataset version: 151508
# MD5: 0486f5b1200ab4c45573eae50db5481b
# Description:
#
# [[64]]
# File (3324660): 20181208-icews-events.zip
# Dataset version: 151508
# MD5: 1da40504fd80268ad92ab77d1146d29d
# Description:
#
# [[65]]
# File (3326255): 20181209-icews-events.zip
# Dataset version: 151508
# MD5: f639faf14318beed30f422783573848e
# Description:
#
# [[66]]
# File (3326558): 20181210-icews-events.zip
# Dataset version: 151508
# MD5: 486bcf196932629ef11d059691812af6
# Description:
#
# [[67]]
# File (3329755): 20181211-icews-events.zip
# Dataset version: 151508
# MD5: 75c0905b9e66a4d6762ea8636ce445ad
# Description:
#
# [[68]]
# File (3329936): 20181212-icews-events.zip
# Dataset version: 151508
# MD5: dce6d1106558e54d2b75d8e4b747c6f5
# Description:
#
# [[69]]
# File (3330645): 20181213-icews-events.zip
# Dataset version: 151508
# MD5: 143d75e1093d2de1561795863b4d291b
# Description:
#
# [[70]]
# File (3330911): 20181214-icews-events.zip
# Dataset version: 151508
# MD5: 9490bd82106cf58b305ecfb246dd623f
# Description:
#
# [[71]]
# File (3332392): 20181215-icews-events.zip
# Dataset version: 151508
# MD5: fa8889bedca85dd53b2e3e5fe05fd0c0
# Description:
#
# [[72]]
# File (3332510): 20181216-icews-events.zip
# Dataset version: 151508
# MD5: 5446270e92929bf5e565d0fc70d02c16
# Description:
#
# [[73]]
# File (3332904): 20181217-icews-events.zip
# Dataset version: 151508
# MD5: 424411bfb8e9d2854e7d9a76cfd14827
# Description:
#
# [[74]]
# File (3333301): 20181218-icews-events.zip
# Dataset version: 151508
# MD5: 998bcc2d6a790e0c4b2256d4e4a76fd5
# Description:
#
# [[75]]
# File (3333628): 20181219-icews-events.zip
# Dataset version: 151508
# MD5: f58d801aebd5b540f63ad0c882bdf521
# Description:
#
# [[76]]
# File (3333772): 20181220-icews-events.zip
# Dataset version: 151508
# MD5: 6b290d75b6278547e4e2455c388586c5
# Description:
#
# [[77]]
# File (3333975): 20181221-icews-events.zip
# Dataset version: 151508
# MD5: 189b38127e6309338e319125c243203c
# Description:
#
# [[78]]
# File (3337596): 20181222-icews-events.zip
# Dataset version: 151508
# MD5: c72c5c1c45af2f55ea6b4cde5a667e44
# Description:
#
# [[79]]
# File (3337597): 20181223-icews-events.zip
# Dataset version: 151508
# MD5: d64822e420d0ba4d110e2f7b89ae4905
# Description:
#
# [[80]]
# File (3337598): 20181224-icews-events.zip
# Dataset version: 151508
# MD5: c662a4a3daeedfc38db0209bb97ff03a
# Description:
#
# [[81]]
# File (3337599): 20181225-icews-events.zip
# Dataset version: 151508
# MD5: ce638e8d5bd4cf931b11d2466f8772d7
# Description:
#
# [[82]]
# File (3337600): 20181226-icews-events.zip
# Dataset version: 151508
# MD5: e5e67e46cc608e7f280b7b0f53822ece
# Description:
#
# [[83]]
# File (3337601): 20181227-icews-events.zip
# Dataset version: 151508
# MD5: daf163394b37ff508bed8b7e08314a8c
# Description:
#
# [[84]]
# File (3337602): 20181228-icews-events.zip
# Dataset version: 151508
# MD5: 7b1d453647c219db73e9932bf045f47f
# Description:
#
# [[85]]
# File (3337603): 20181229-icews-events.zip
# Dataset version: 151508
# MD5: b97132daf84fbaf797496896c6ebf5de
# Description:
#
# [[86]]
# File (3337604): 20181230-icews-events.zip
# Dataset version: 151508
# MD5: 2d61078c91170ccdfd1bbe6cdbd1d39a
# Description:
#
# [[87]]
# File (3337605): 20181231-icews-events.zip
# Dataset version: 151508
# MD5: e9a38f5d318f7936bb3fddf6f237cf33
# Description:
#
# [[88]]
# File (3337606): 20190101-icews-events.zip
# Dataset version: 151508
# MD5: dea3c4b42766e1b5827cce393de86195
# Description:
#
# [[89]]
# File (3337607): 20190102-icews-events.zip
# Dataset version: 151508
# MD5: 10a50ebd05a1e365b475331df3fdf1b1
# Description:
#
# [[90]]
# File (3337608): 20190103-icews-events.zip
# Dataset version: 151508
# MD5: 9e4a75919e4d4764acf3ca34c2707a55
# Description:
#
# [[91]]
# File (3337630): 20190104-icews-events.zip
# Dataset version: 151508
# MD5: 65627c3df6ff247381b388926169ca71
# Description:
#
# [[92]]
# File (3337648): 20190105-icews-events.zip
# Dataset version: 151508
# MD5: 265f23305a4bba869c5bbeb179aeac8e
# Description:
#
# [[93]]
# File (3337686): 20190106-icews-events.zip
# Dataset version: 151508
# MD5: 24742f8a25610ebb1f6ae04c6ea5956a
# Description:
#
# [[94]]
# File (3338310): 20190107-icews-events.zip
# Dataset version: 151508
# MD5: 17c5fec7e10f920d10212e3ae9e75500
# Description:
#
# [[95]]
# File (3339220): 20190108-icews-events.zip
# Dataset version: 151508
# MD5: 2328350ff5f0c84caaf89bfd4c0bcce6
# Description:
#
# [[96]]
# File (3340522): 20190109-icews-events.zip
# Dataset version: 151508
# MD5: baafeaa1b48020ac403c9a15c12ca7b4
# Description:
#
# [[97]]
# File (3344121): 20190110-icews-events.zip
# Dataset version: 151508
# MD5: fcabea21f1bb87929bad8a1ea9eb6f2b
# Description:
#
# [[98]]
# File (3344489): 20190111-icews-events.zip
# Dataset version: 151508
# MD5: 0eab4ddd018031b3ff1b359b2e080c6d
# Description:
#
# [[99]]
# File (3344662): 20190112-icews-events.zip
# Dataset version: 151508
# MD5: 026c7cb95b70d6c3ba0c2b454592cd93
# Description:
#
# [[100]]
# File (3344730): 20190113-icews-events.zip
# Dataset version: 151508
# MD5: a8799475dc7ad57142b25a0f788901f8
# Description:
#
# [[101]]
# File (3344814): 20190114-icews-events.zip
# Dataset version: 151508
# MD5: 085e30188131ac5aa5ca6d63b6dd00a6
# Description:
#
# [[102]]
# File (3344929): 20190115-icews-events.zip
# Dataset version: 151508
# MD5: 75314986ebe3b1fe62a94facde07e74a
# Description:
#
# [[103]]
# File (3345449): 20190116-icews-events.zip
# Dataset version: 151508
# MD5: 9f8c8ec7a045c21993fb5665c893161d
# Description:
#
# [[104]]
# File (3345450): 20190117-icews-events.zip
# Dataset version: 151508
# MD5: db99c161a47d19b53982617dd8983576
# Description:
#
# [[105]]
# File (3346475): 20190118-icews-events.zip
# Dataset version: 151508
# MD5: 11bf6901751d6178917d4b1690060ccd
# Description:
#
# [[106]]
# File (3346476): 20190119-icews-events.zip
# Dataset version: 151508
# MD5: be76e1927c6f29fd6748a543d679464b
# Description:
#
# [[107]]
# File (3346477): 20190120-icews-events.zip
# Dataset version: 151508
# MD5: 82813afc046329331e033ac92d6b4199
# Description:
#
# [[108]]
# File (3346663): 20190121-icews-events.zip
# Dataset version: 151508
# MD5: a821eff901658e4424164f826daf050d
# Description:
#
# [[109]]
# File (3346873): 20190122-icews-events.zip
# Dataset version: 151508
# MD5: a00db55b19fd52573c81352158341e35
# Description:
#
# [[110]]
# File (3346971): 20190123-icews-events.zip
# Dataset version: 151508
# MD5: 4057bef5c03c04ad3123dffc6d9c3999
# Description:
#
# [[111]]
# File (3347274): 20190124-icews-events.zip
# Dataset version: 151508
# MD5: 1025a5a9b9271d6476cbc23997e1ea47
# Description:
#
# [[112]]
# File (3347585): 20190125-icews-events.zip
# Dataset version: 151508
# MD5: d9d16514257c44fc26a5ad180761129a
# Description:
#
# [[113]]
# File (3347811): 20190126-icews-events.zip
# Dataset version: 151508
# MD5: fafe8c712db5f5394b91a9209edbcea5
# Description:
#
# [[114]]
# File (3348320): 20190127-icews-events.zip
# Dataset version: 151508
# MD5: aac1a228b8235db59cfebfec808d3ae9
# Description:
#
# [[115]]
# File (3348680): 20190128-icews-events.zip
# Dataset version: 151508
# MD5: 5df797883580f05e3c208b132582dbcd
# Description:
#
# [[116]]
# File (3349094): 20190129-icews-events.zip
# Dataset version: 151508
# MD5: fe00ab161d21d4f7de070b158a802db0
# Description:
#
# [[117]]
# File (3349359): 20190130-icews-events.zip
# Dataset version: 151508
# MD5: 5a85aee71bb6ed0c7f8afdd19333faf7
# Description:
#
# [[118]]
# File (3349524): 20190131-icews-events.zip
# Dataset version: 151508
# MD5: 6186d4ceb2a3240c0be1ccebbbd76662
# Description:
#
# [[119]]
# File (3350396): 20190201-icews-events.zip
# Dataset version: 151508
# MD5: e3095d3e3f729fba0f0d4ddec436966a
# Description:
#
# [[120]]
# File (3350722): 20190202-icews-events.zip
# Dataset version: 151508
# MD5: 7c72513371a2b39288b2c4773e70d7f5
# Description:
#
# [[121]]
# File (3350747): 20190203-icews-events.zip
# Dataset version: 151508
# MD5: 44cc0c1312c1e64ce1956bdf77fdf32e
# Description:
#
# [[122]]
# File (3350994): 20190204-icews-events.zip
# Dataset version: 151508
# MD5: bd1709bc05b56348de8e9b17be17483f
# Description:
#
# [[123]]
# File (3354195): 20190205-icews-events.zip
# Dataset version: 151508
# MD5: fd184e06c56441aa893bc0d9616a221b
# Description:
#
# [[124]]
# File (3354514): 20190206-icews-events.zip
# Dataset version: 151508
# MD5: 0204a400636fc22b085b98789606b93c
# Description:
#
# [[125]]
# File (3354892): 20190207-icews-events.zip
# Dataset version: 151508
# MD5: 40a33091a99b15dc9460bc4014d1f0b3
# Description:
#
# [[126]]
# File (3355363): 20190208-icews-events.zip
# Dataset version: 151508
# MD5: 60832ac4f0ecaae71a0ec00c60b62025
# Description:
#
# [[127]]
# File (3357452): 20190211-icews-events.zip
# Dataset version: 151508
# MD5: ad0badf269787b19f419f4d552f2cc48
# Description:
#
# [[128]]
# File (3357554): 20190212-icews-events.zip
# Dataset version: 151508
# MD5: 134c45e54390fa47d603208f51e2e830
# Description:
#
# [[129]]
# File (3357699): 20190213-icews-events.zip
# Dataset version: 151508
# MD5: e3f6849623015dbd61d69720e844725a
# Description:
#
# [[130]]
# File (3360844): 20190214-icews-events.zip
# Dataset version: 151508
# MD5: 693eb669e00126d1236bd290490c05f0
# Description:
#
# [[131]]
# File (3362203): 20190215-icews-events.zip
# Dataset version: 151508
# MD5: 6219b9ead9cbdc9b0ebec73e6560e454
# Description:
#
# [[132]]
# File (3362266): 20190216-icews-events.zip
# Dataset version: 151508
# MD5: e5796153a9f956d1ac4a07f3de294a67
# Description:
#
# [[133]]
# File (3362273): 20190217-icews-events.zip
# Dataset version: 151508
# MD5: 399ec370b15e3646865b47feef311144
# Description:
#
# [[134]]
# File (3364293): 20190218-icews-events.zip
# Dataset version: 151508
# MD5: 2eaa15e6550304c809b3a76c5da09f86
# Description:
#
# [[135]]
# File (3365277): 20190219-icews-events.zip
# Dataset version: 151508
# MD5: 0828ab65e008779edaf3638ad0f8f449
# Description:
#
# [[136]]
# File (3370401): 20190220-icews-events.zip
# Dataset version: 151508
# MD5: 1dd472e2ad143a512caa2e88ef3cf03a
# Description:
#
# [[137]]
# File (3370578): 20190221-icews-events.zip
# Dataset version: 151508
# MD5: 98f5ddc51dac992bf3711cc66eb20c1f
# Description:
#
# [[138]]
# File (3371154): 20190222-icews-events.zip
# Dataset version: 151508
# MD5: 15008eeadf0dcbbc92625685ba22f91f
# Description:
#
# [[139]]
# File (3371183): 20190223-icews-events.zip
# Dataset version: 151508
# MD5: 064c2609a4568d29c79e89995be9fc4c
# Description:
#
# [[140]]
# File (3371223): 20190224-icews-events.zip
# Dataset version: 151508
# MD5: bf8c1eca0039e236789400a602eab5f7
# Description:
#
# [[141]]
# File (3371553): 20190225-icews-events.zip
# Dataset version: 151508
# MD5: 68c0374fe8d901a2a5c5b32a3cf60503
# Description:
#
# [[142]]
# File (3372147): 20190226-icews-events.zip
# Dataset version: 151508
# MD5: 5849485b38c17895f7f13a5c85064f8a
# Description:
#
# [[143]]
# File (3373117): 20190227-icews-events.zip
# Dataset version: 151508
# MD5: fc6d66f511f25ed69746776a12d01fc6
# Description:
#
# [[144]]
# File (3373626): 20190228-icews-events.zip
# Dataset version: 151508
# MD5: b4edbab6713b6ccd4081c067234e6b8b
# Description:
#
# [[145]]
# File (3373922): 20190301-icews-events.zip
# Dataset version: 151508
# MD5: 22f77cbbbb1f5a8ca047141947839030
# Description:
#
# [[146]]
# File (3374037): 20190302-icews-events.zip
# Dataset version: 151508
# MD5: 4723e83ac8bc4db9bda32204474fa374
# Description:
#
# [[147]]
# File (3376340): 20190303-icews-events.zip
# Dataset version: 151508
# MD5: 8ca11b82cbbdd179df323d253a2a522e
# Description:
#
# [[148]]
# File (3376530): 20190304-icews-events.zip
# Dataset version: 151508
# MD5: c6c1f7b365ab926c5f193fd27eb53975
# Description:
#
# [[149]]
# File (3376746): 20190305-icews-events.zip
# Dataset version: 151508
# MD5: 8ca6579c9ef7e84effc50f5f1a2221c4
# Description:
#
# [[150]]
# File (3376828): 20190306-icews-events.zip
# Dataset version: 151508
# MD5: 4bc50d54d121d569d33c061491226f86
# Description:
#
# [[151]]
# File (3377068): 20190307-icews-events.zip
# Dataset version: 151508
# MD5: 02a90b2f82e8666b0d54cf3c275d7179
# Description:
#
# [[152]]
# File (3377299): 20190308-icews-events.zip
# Dataset version: 151508
# MD5: 26b8ce2f11371f7d3e25dfe998b88ba1
# Description:
#
# [[153]]
# File (3377732): 20190309-icews-events.zip
# Dataset version: 151508
# MD5: c5bc6ece541e128c7ba6dcbe6f2fdf6d
# Description:
#
# [[154]]
# File (3377320): 20190309-icews-events.zip
# Dataset version: 151508
# MD5: da91258b8aaa6d9567447d804db56b11
# Description:
#
# [[155]]
# File (3377961): 20190311-icews-events.zip
# Dataset version: 151508
# MD5: d92d6bf60a3d68ef00405a7ca7071cb0
# Description:
#
# [[156]]
# File (3378405): 20190312-icews-events.zip
# Dataset version: 151508
# MD5: f1102e47405e37998102f88e52d7ad48
# Description:
#
# [[157]]
# File (3378464): 20190313-icews-events.zip
# Dataset version: 151508
# MD5: 4328cfeabe419590de5818a7c2a1a8dc
# Description:
#
# [[158]]
# File (3379013): 20190314-icews-events.zip
# Dataset version: 151508
# MD5: 74d67796ac3fdc1dda11e976b211b30a
# Description:
#
# [[159]]
# File (3379435): 20190315-icews-events.zip
# Dataset version: 151508
# MD5: 17ecb7fae9731d2ea315d700fdfae245
# Description:
#
# [[160]]
# File (3379648): 20190316-icews-events.zip
# Dataset version: 151508
# MD5: 5a5da69c6c017b3c771d0252b9d54132
# Description:
#
# [[161]]
# File (3379725): 20190317-icews-events.zip
# Dataset version: 151508
# MD5: abd5c06e3eda652353b5796471202d7f
# Description:
#
# [[162]]
# File (3380832): 20190318-icews-events.zip
# Dataset version: 151508
# MD5: af0bb11b38e4d8cf4116601d4d23a491
# Description:
#
# [[163]]
# File (3381850): 20190319-icews-events.zip
# Dataset version: 151508
# MD5: c0cf001cf81e4225f6e72ec298b173a9
# Description:
#
# [[164]]
# File (3382048): 20190320-icews-events.zip
# Dataset version: 151508
# MD5: 15bbd1f839c3d55f7fc36cf0e59aa076
# Description:
#
# [[165]]
# File (3382524): 20190321-icews-events.zip
# Dataset version: 151508
# MD5: 7f4dd89a12b00286952d16d5cf0f2f51
# Description:
#
# [[166]]
# File (3382662): 20190322-icews-events.zip
# Dataset version: 151508
# MD5: 58199c0a2735fc98668b5ca34a81fc67
# Description:
#
# [[167]]
# File (3382959): 20190323-icews-events.zip
# Dataset version: 151508
# MD5: 06383ce7e2673f26cae144b97849e0a5
# Description:

# %%
data_list[[1]]
# Out:
# File (3234868): 20181004-icews-events.zip
# Dataset version: 151508
# MD5: 9a9a3bcca7df7c6eef0f161fd3cdcd7a
# Description:

# %%
data_list[[1]]['dataFile']
# Out:
# $dataFile
# $dataFile$id
# [1] 3234868
#
# $dataFile$persistentId
# [1] "doi:10.7910/DVN/QI2T9A/0PYTLV"
#
# $dataFile$pidURL
# [1] "https://doi.org/10.7910/DVN/QI2T9A/0PYTLV"
#
# $dataFile$filename
# [1] "20181004-icews-events.zip"
#
# $dataFile$contentType
# [1] "application/zip"
#
# $dataFile$filesize
# [1] 89340
#
# $dataFile$description
# [1] ""
#
# $dataFile$storageIdentifier
# [1] "s3://dvn-cloud:166428fa8b9-468a29c1ebbb"
#
# $dataFile$rootDataFileId
# [1] -1
#
# $dataFile$md5
# [1] "9a9a3bcca7df7c6eef0f161fd3cdcd7a"
#
# $dataFile$checksum
# $dataFile$checksum$type
# [1] "MD5"
#
# $dataFile$checksum$value
# [1] "9a9a3bcca7df7c6eef0f161fd3cdcd7a"

# %%
# this is the easiest form in which to deal with this at the moment. Still, there must be more elegant ways. I'm going to put off looking for them until later in the project.
unlist(data_list[[1]])
# Out:
#                                 description
#                                          ""
#                                       label
#                 "20181004-icews-events.zip"
#                                  restricted
#                                     "FALSE"
#                                     version
#                                         "1"
#                            datasetVersionId
#                                    "151508"
#                                 dataFile.id
#                                   "3234868"
#                       dataFile.persistentId
#             "doi:10.7910/DVN/QI2T9A/0PYTLV"
#                             dataFile.pidURL
# "https://doi.org/10.7910/DVN/QI2T9A/0PYTLV"
#                           dataFile.filename
#                 "20181004-icews-events.zip"
#                        dataFile.contentType
#                           "application/zip"
#                           dataFile.filesize
#                                     "89340"
#                        dataFile.description
#                                          ""
#                  dataFile.storageIdentifier
#   "s3://dvn-cloud:166428fa8b9-468a29c1ebbb"
#                     dataFile.rootDataFileId
#                                        "-1"
#                                dataFile.md5
#          "9a9a3bcca7df7c6eef0f161fd3cdcd7a"
#                      dataFile.checksum.type
#                                       "MD5"
#                     dataFile.checksum.value
#          "9a9a3bcca7df7c6eef0f161fd3cdcd7a"

# %%
# test handle
url = 'https://dataverse.harvard.edu/api/access/datafile/3382959'

# %%
# downloading from URL. The docs warn against this, in the case of large datasets. Not something we need to worry about, exactly, since all our datasets are pretty small and zipped at present (<200kb zipped). Still, in production, this should be avoided
download.file(url, 'test.zip', 'wget')
